# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 1. 데이터 로드
file_path = '../data/seoul_subway_data.csv'  # 파일 경로는 실제 파일 위치에 맞게 수정하세요.
data = pd.read_csv(file_path)
data
# Out:
#           Date  DayOfWeek   Time  PassengerCount
# 0   2023-09-01     Friday  08:00            1200
# 1   2023-09-01     Friday  09:00             900
# 2   2023-09-01     Friday  10:00             500
# 3   2023-09-02   Saturday  08:00             300
# 4   2023-09-02   Saturday  09:00             200
# 5   2023-09-02   Saturday  10:00             150
# 6   2023-09-03     Sunday  08:00             100
# 7   2023-09-03     Sunday  09:00              80
# 8   2023-09-03     Sunday  10:00              70
# 9   2023-09-04     Monday  08:00            1300
# 10  2023-09-04     Monday  09:00            1100
# 11  2023-09-04     Monday  10:00             700
# 12  2023-09-05    Tuesday  08:00            1400
# 13  2023-09-05    Tuesday  09:00            1200
# 14  2023-09-05    Tuesday  10:00             800
# 15  2023-09-06  Wednesday  08:00            1500
# 16  2023-09-06  Wednesday  09:00            1300
# 17  2023-09-06  Wednesday  10:00             900
# 18  2023-09-07   Thursday  08:00            1600
# 19  2023-09-07   Thursday  09:00            1400
# 20  2023-09-07   Thursday  10:00            1000

# %%
# 2. 요일별 이용객 수 집계
weekday_agg = data.groupby('DayOfWeek')['PassengerCount'].sum()
print(weekday_agg)
# Out:
# DayOfWeek
# Friday       2600
# Monday       3100
# Saturday      650
# Sunday        250
# Thursday     4000
# Tuesday      3400
# Wednesday    3700
# Name: PassengerCount, dtype: int64

# %%
# 2. 시간대별 이용객 수 집계
time_agg = data.groupby('Time')['PassengerCount'].sum()
print(time_agg)
# Out:
# Time
# 08:00    7400
# 09:00    6180
# 10:00    4120
# Name: PassengerCount, dtype: int64

# %%
# 3. 요일별 이용객 수 가로 막대 그래프 시각화
plt.figure(figsize=(10, 6))
weekday_agg.reindex(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']).plot(kind='barh', color='skyblue')
plt.title('Total Passengers by Day of the Week')
plt.xlabel('Passenger Count')
plt.ylabel('Day of the Week')
plt.show()

# %%
# 4. 시간대별 이용객 수 꺾은선 그래프 시각화
plt.figure(figsize=(10, 6))
time_agg.plot(kind='line', color='blue', marker='o')
plt.title('Total Passengers by Time of Day')
plt.xlabel('Time')
plt.ylabel('Passenger Count')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
