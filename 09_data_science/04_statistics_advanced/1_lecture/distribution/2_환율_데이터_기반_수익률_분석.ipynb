# %%
# !pip install finance-datareader
# Out:
# Collecting finance-datareader
#   Downloading finance_datareader-0.9.96-py3-none-any.whl.metadata (12 kB)
# Collecting beautifulsoup4 (from finance-datareader)
#   Downloading beautifulsoup4-4.13.5-py3-none-any.whl.metadata (3.8 kB)
# Collecting lxml (from finance-datareader)
#   Downloading lxml-6.0.1-cp311-cp311-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: pandas>=1.1.0 in c:\users\ssafy\appdata\local\programs\python\python311\lib\site-packages (from finance-datareader) (2.3.2)
# Collecting plotly (from finance-datareader)
#   Downloading plotly-6.3.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting requests-file (from finance-datareader)
#   Downloading requests_file-2.1.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: requests>=2.3.0 in c:\users\ssafy\appdata\local\programs\python\python311\lib\site-packages (from finance-datareader) (2.32.4)
# Requirement already satisfied: tqdm in c:\users\ssafy\appdata\local\programs\python\python311\lib\site-packages (from finance-datareader) (4.67.1)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\ssafy\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.1.0->finance-datareader) (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ssafy\appdata\roaming\python\python311\site-packages (from pandas>=1.1.0->finance-datareader) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ssafy\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.1.0->finance-datareader) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ssafy\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.1.0->finance-datareader) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ssafy\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.3.0->finance-datareader) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ssafy\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.3.0->finance-datareader) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ssafy\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.3.0->finance-datareader) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ssafy\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.3.0->finance-datareader) (2025.7.14)
# Collecting soupsieve>1.2 (from beautifulsoup4->finance-datareader)
#   Downloading soupsieve-2.8-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\ssafy\appdata\roaming\python\python311\site-packages (from beautifulsoup4->finance-datareader) (4.14.1)
# Collecting narwhals>=1.15.1 (from plotly->finance-datareader)
#   Downloading narwhals-2.5.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging in c:\users\ssafy\appdata\roaming\python\python311\site-packages (from plotly->finance-datareader) (25.0)
# Requirement already satisfied: colorama in c:\users\ssafy\appdata\roaming\python\python311\site-packages (from tqdm->finance-datareader) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\ssafy\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas>=1.1.0->finance-datareader) (1.17.0)
# Downloading finance_datareader-0.9.96-py3-none-any.whl (48 kB)
#    ---------------------------------------- 0.0/48.2 kB ? eta -:--:--
#    ---------------------------------------- 48.2/48.2 kB ? eta 0:00:00
# Downloading beautifulsoup4-4.13.5-py3-none-any.whl (105 kB)
#    ---------------------------------------- 0.0/105.1 kB ? eta -:--:--
#    ---------------------------------------- 105.1/105.1 kB 6.3 MB/s eta 0:00:00
# Downloading lxml-6.0.1-cp311-cp311-win_amd64.whl (4.0 MB)
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ------ --------------------------------- 0.6/4.0 MB 12.9 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.7/4.0 MB 17.6 MB/s eta 0:00:01
#    -------------------------------- ------- 3.2/4.0 MB 22.9 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 23.4 MB/s eta 0:00:00
# Downloading plotly-6.3.0-py3-none-any.whl (9.8 MB)
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ------------ --------------------------- 3.0/9.8 MB 62.7 MB/s eta 0:00:01
#    ------------- -------------------------- 3.3/9.8 MB 34.6 MB/s eta 0:00:01
#    ------------- -------------------------- 3.3/9.8 MB 26.5 MB/s eta 0:00:01
#    ------------- -------------------------- 3.4/9.8 MB 19.8 MB/s eta 0:00:01
#    -------------- ------------------------- 3.5/9.8 MB 15.0 MB/s eta 0:00:01
#    --------------- ------------------------ 3.7/9.8 MB 13.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 4.2/9.8 MB 12.7 MB/s eta 0:00:01
#    ------------------------------- -------- 7.6/9.8 MB 20.3 MB/s eta 0:00:01
#    ---------------------------------------  9.8/9.8 MB 24.0 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 22.3 MB/s eta 0:00:00
# Downloading requests_file-2.1.0-py2.py3-none-any.whl (4.2 kB)
# Downloading narwhals-2.5.0-py3-none-any.whl (407 kB)
#    ---------------------------------------- 0.0/407.3 kB ? eta -:--:--
#    --------------------------------------- 407.3/407.3 kB 24.8 MB/s eta 0:00:00
# Downloading soupsieve-2.8-py3-none-any.whl (36 kB)
# Installing collected packages: soupsieve, narwhals, lxml, requests-file, plotly, beautifulsoup4, finance-datareader
# Successfully installed beautifulsoup4-4.13.5 finance-datareader-0.9.96 lxml-6.0.1 narwhals-2.5.0 plotly-6.3.0 requests-file-2.1.0 soupsieve-2.8
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import FinanceDataReader as fdr  # 금융 데이터를 쉽게 불러오는 라이브러리
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
plt.rcParams["font.family"] = "Malgun Gothic"

# %%
# 1. USD/KRW 환율 데이터 불러오기
df = fdr.DataReader('USD/KRW', '2023-07-10', '2025-07-10') # 3년치 데이터 가져오기
#df.describe()
df = df[['Close']] # 종가 (Close) 데이터만 사용
df = df.rename(columns={'Close' : '환율'}) # 컬럼명 변경

# 2. 환율 변동률(수익률) 계산
df['환율 수익률'] = df['환율'].pct_change() * 100 # 퍼센트(%) 변동률로 변환
df = df.dropna() # 첫 번째 NaN 값 제거

# 3. 히스토그램 그리기
plt.figure(figsize=(12, 6))
plt.hist(df['환율 수익률'], bins=50, density=True, alpha=0.7, color='blue')
plt.title('USD/KRW 환율 변동률 분포')
plt.xlabel('환율 변동률 (%)')
plt.ylabel('빈도')
plt.grid(True)
plt.show()

# 4. QQ-Plot 그리기 (정규성 확인)
plt.figure(figsize=(8, 8))
stats.probplot(df['환율 수익률'], dist='norm', plot=plt)
plt.title("USD/KRW 환율 QQ-Plot")
plt.show()
# Out:
# C:\Users\SSAFY\AppData\Local\Temp\ipykernel_7396\3837963398.py:8: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   df['환율 수익률'] = df['환율'].pct_change() * 100 # 퍼센트(%) 변동률로 변환
# C:\Users\SSAFY\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) Malgun Gothic.
#   fig.canvas.print_figure(bytes_io, **kw)
