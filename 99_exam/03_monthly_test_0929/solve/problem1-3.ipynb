# %%
# 문제1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 데이터 로드
file_path = 'data/seoul_traffic_data.csv'
traffic_data = pd.read_csv(file_path)

traffic_data
# Out:
#             date district  temperature  precipitation  num_vehicles  \
# 0     2023-04-13      서초구    -1.971793      23.419412          8230
# 1     2023-12-15      강서구    12.788840       1.572606          5362
# 2     2023-09-28      마포구    13.508233       7.186694          7176
# 3     2023-04-17      강서구    22.650517       0.305907          2832
# 4     2023-03-13      강남구     5.461658       3.150569          7183
# ...          ...      ...          ...            ...           ...
# 9995  2023-05-28      강남구    25.620435       2.491726          5425
# 9996  2023-12-31      종로구    -8.454456       1.236016          8059
# 9997  2023-12-30      서초구     0.775386       2.848569          1875
# 9998  2023-05-20      강남구    10.602225       3.179578          6840
# 9999  2023-07-09      종로구     3.111571       0.683861          3288
#
#       num_pedestrians  day_of_week  is_weekend  month  traffic_volume  \
# 0                 683            3           0      4            6528
# 1                 884            4           0     12            6287
# 2                 700            3           0      9            9597
# 3                 119            0           0      4            3450
# 4                 414            0           0      3            7867
# ...               ...          ...         ...    ...             ...
# 9995              537            6           1      5            7027
# 9996              324            6           1     12            7703
# 9997              302            5           1     12            1463
# 9998              140            5           1      5            8432
# 9999              954            6           1      7            5635
#
#       avg_speed
# 0         49.44
# 1         48.74
# 2         45.30
# 3         50.20
# 4         46.86
# ...         ...
# 9995      53.74
# 9996      54.91
# 9997      61.52
# 9998      52.64
# 9999      45.71
#
# [10000 rows x 11 columns]

# %%
# 문제 01. 온도와 교통량 간의 관계 분석
def temperature_vs_traffic(traffic_data):
    ################### 코드 작성 ###################
    # Temperature과 Traffic Volume를 보여주는 산점도 그리기
    plt.scatter(traffic_data['temperature'], traffic_data['traffic_volume'])
    ###############################################
    plt.title('Temperature vs Traffic Volume')  # 제목
    plt.xlabel('Temperature (C)')  # x축 레이블
    plt.ylabel('Traffic Volume')  # y축 레이블
    plt.show()

    ################### 코드 작성 ###################
    # 상관 계수 계산
    # correlation = _____________
    ###############################################
    # print(f"Correlation coefficient between temperature and traffic volume: {correlation:.4f}")

# %%
# 문제 02. 강수량과 평균 속도 간의 관계 분석
def precipitation_vs_avg_speed(traffic_data):
    ################### 코드 작성 ###################

    # 평균 속도 계산
    avg_speed_rainy = traffic_data[traffic_data['precipitation'] >= 0.2]['avg_speed'].mean() # 비 오는 날의 평균 속도
    avg_speed_non_rainy = traffic_data[traffic_data['precipitation'] < 0.2]['avg_speed'].mean() # 비 오지 않는 날의 평균 속도
    
    ###############################################

    print(f"Average speed on rainy days: {avg_speed_rainy:.2f} km/h")
    print(f"Average speed on non-rainy days: {avg_speed_non_rainy:.2f} km/h")

# %%
# 문제 03. 요일별 교통량 패턴 분석
def day_of_week_vs_traffic(traffic_data):
    ################### 코드 작성 ###################
    # 요일별 평균 교통량 계산하여 막대그래프로 시각화
    monday = traffic_data[traffic_data['day_of_week'] == 0]['traffic_volume'].mean()
    tuesday = traffic_data[traffic_data['day_of_week'] == 1]['traffic_volume'].mean()
    wednesday = traffic_data[traffic_data['day_of_week'] == 2]['traffic_volume'].mean()
    thursday = traffic_data[traffic_data['day_of_week'] == 3]['traffic_volume'].mean()
    friday = traffic_data[traffic_data['day_of_week'] == 4]['traffic_volume'].mean()
    saturday = traffic_data[traffic_data['day_of_week'] == 5]['traffic_volume'].mean()
    sunday = traffic_data[traffic_data['day_of_week'] == 6]['traffic_volume'].mean()
    plt.bar([0, 1, 2, 3, 4, 5, 6], [monday, tuesday, wednesday, thursday, friday, saturday, sunday])
    ###############################################
    plt.title('Average Traffic Volume per Day of the Week')  # 제목
    plt.xlabel('Day of Week (0=Mon, 6=Sun)')  # x축 레이블
    plt.ylabel('Average Traffic Volume')  # y축 레이블
    plt.show()

    # 주말과 평일 교통량 비교
    ################### 코드 작성 ###################
    avg_weekend_traffic = traffic_data[traffic_data['is_weekend'] == 1]['traffic_volume'].mean() # 주말의 평균 교통량
    avg_weekday_traffic = traffic_data[traffic_data['is_weekend'] == 0]['traffic_volume'].mean() # 평일의 평균 교통량
    ###############################################

    print(f"Average weekend traffic: {avg_weekend_traffic:.2f}")
    print(f"Average weekday traffic: {avg_weekday_traffic:.2f}")

# %%
# Execute the functions
temperature_vs_traffic(traffic_data)
precipitation_vs_avg_speed(traffic_data)
day_of_week_vs_traffic(traffic_data)
# Out:
# Average speed on rainy days: 49.89 km/h
# Average speed on non-rainy days: 49.98 km/h
# Average weekend traffic: 6883.08
# Average weekday traffic: 5930.98
